# %% [markdown]
# <a href="https://colab.research.google.com/github/samezqui/fullofstars/blob/constellations/df_Constellations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np 

df = pd.read_csv('/content/drive/My Drive/Constellations.csv')


for idx,val in df.iterrows():
  df.loc[idx,'vis_mag'] = float(df.loc[idx,'vis_mag'])
  
  
df = df[df['vis_mag'] <= 2.5] # Bigger number = more stars 
print('After filtering, there are {} stars'.format(len(df)))
# Stars we are able to see by the naked eye on a clear night 

df
# Out:
# After filtering, there are 20 stars
#      Constellations         Name      HIP               RA             Dec  \
# 0          Andromeda       α And    677.0   00h 08m 23.17s  +29° 05′ 27.0″
# 1          Andromeda       β And   5447.0   01h 09m 43.80s  +35° 37′ 15.0″
# 2          Andromeda      γ1 And   9640.0   02h 03m 53.92s  +42° 19′ 47.5″
# 178            Aries       α And    677.0   00h 08m 23.17s  +29° 05′ 27.0″
# 179            Aries       β And   5447.0   01h 09m 43.80s  +35° 37′ 15.0″
# 180            Aries      γ1 And   9640.0   02h 03m 53.92s  +42° 19′ 47.5″
# 356       Cassiopeia       γ Cas   4427.0   00h 56m 42.50s  +60° 43′ 00.3″
# 357       Cassiopeia       α Cas   3179.0   00h 40m 30.39s  +56° 32′ 14.7″
# 358       Cassiopeia       β Cas    746.0   00h 09m 10.09s  +59° 09′ 00.8″
# 672            Orion       Rigel  24436.0   05h 14m 32.27s  −08° 12′ 05.9″
# 673            Orion  Betelgeuse  27989.0   05h 55m 10.29s  +07° 24′ 25.3″
# ...

# %% [markdown]
# ##Find Stars for each Unique Constellation
# Starting with Andromeda
#
# Figured this out using HW 6 as a reference!!!

# %%
names = df['Constellations '].unique() # np.ndarray of Constellations that make filter
print(names)
# print(type(names))
# print(names[0])

num_cons = len(names) # number of constellations 
print(num_cons)

sam_df = pd.DataFrame(index=names,columns=['ra','dec'])
# index = names 

# find how many unique stars are in a constellation
for val in range(0,num_cons):
  cons_df = pd.DataFrame()
  
  one_sample = df['Constellations '] == names[val]
  star_num = len(df.loc[one_sample,'RA'].unique())
  cons_df.loc[names[val],'data'] = df.loc[one_sample]
  
  print(star_num)
 
  print(cons_df)
  
# use length value to index through the constellation name tag
  for val2 in range(0,star_num-1):
    sam_df.loc[names[val],'ra'] = np.append(df.loc[sample[val2],'RA'])
    sam_df.loc[names[val],'dec'] = np.append(df.loc[sample[val2],'Dec'])
# append RA and dec
# andro = df['Constellations'] == names[0]


#sam_df.loc[names[0],'dec'] = np.append(df.loc[andro,'dec'])

# convert strings so they can be used in SkyCoord

sam_df

for val in range(0,len(df)-1):
   x=1 # placer
    
   # one_sample = df['Date'].dt.year == val
   # sam_df.loc[val,'Num_Storms'] = len(df.loc[one_sample,'ID'].unique())
# Out:
# ['Andromeda' 'Aries' 'Cassiopeia' 'Orion' 'Perseus ' 'Taurus ']
# 6
# 3
#            data
# Andromeda   NaN
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# ...
